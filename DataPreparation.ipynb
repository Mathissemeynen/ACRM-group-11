# %%
# import packages
import os
import math
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import plotly.graph_objects as go
from datetime import datetime
import seaborn as sns

# %%
# read in all the data
facilities = pd.read_csv('./Data/facilities.csv')
incidents = pd.read_csv('./Data/incidents.csv')
satisfaction = pd.read_csv('./Data/satisfaction.csv')
stations = pd.read_csv('./Data/stations.csv')
stops = pd.read_csv('./Data/stops.csv')
subscriptions = pd.read_csv('./Data/subscriptions.csv')
tickets = pd.read_csv('./Data/tickets.csv')
travelers = pd.read_csv('./Data/travelers.csv', sep=';')

# %%
# Only keep all Belgian stations 
facilities = facilities[facilities['zip'].notna()]
stations = stations[stations['country-code'] == 'be']

# %%
# Merge stations and facilities based on station_id
stations_facilities = pd.merge(stations, facilities, on='station_id', how='outer')
stations_facilities
# Out:
#      station_id                 name_x alternative-fr alternative-nl  \
# 0       8811007  Schaarbeek/Schaerbeek     Schaerbeek     Schaarbeek
# 1       8811106                  Evere            NaN            NaN
# 2       8811130   Haren-Sud/Haren-Zuid      Haren-Sud     Haren-Zuid
# 3       8811148                   Buda            NaN            NaN
# 4       8811155                  Haren            NaN            NaN
# ..          ...                    ...            ...            ...
# 569     8896503                  Ieper          Ypres            NaN
# 570     8896735              Poperinge            NaN            NaN
# 571     8896800              Roeselare        Roulers            NaN
# 572     8896909                 Izegem            NaN            NaN
# 573     8896925           Ingelmunster            NaN            NaN
#
#     alternative-de alternative-en country-code  longitude   latitude  \
# 0              NaN            NaN           be   4.378636  50.878513
# 1              NaN            NaN           be   4.400965  50.867780
# 2              NaN            NaN           be   4.415357  50.889696
# 3              NaN            NaN           be   4.417074  50.907495
# 4              NaN            NaN           be   4.419978  50.888878
# ..             ...            ...          ...        ...        ...
# 569            NaN            NaN           be   2.876593  50.847402
# 570            NaN            NaN           be   2.736343  50.854449
# 571            NaN            NaN           be   3.130412  50.949025
# 572            NaN            NaN           be   3.212088  50.921149
# 573            NaN            NaN           be   3.255416  50.914326
#
#      avg_stop_times  ...  sales_open_wednesday sales_close_wednesday  \
# 0        737.231343  ...                   NaN                   NaN
# 1        166.641791  ...                   NaN                   NaN
# 2        324.111940  ...                   NaN                   NaN
# 3        208.134328  ...                   NaN                   NaN
# 4        166.641791  ...                   NaN                   NaN
# ..              ...  ...                   ...                   ...
# 569       42.067164  ...                 06:00                 13:15
# 570       41.544776  ...                 05:45                 11:10
# 571       68.574627  ...                 06:15                 20:00
# 572       68.574627  ...                 06:00                 13:15
# 573       68.574627  ...                   NaN                   NaN
#
#     sales_open_thursday sales_close_thursday sales_open_friday  \
# 0                   NaN                  NaN               NaN
# 1                   NaN                  NaN               NaN
# 2                   NaN                  NaN               NaN
# 3                   NaN                  NaN               NaN
# 4                   NaN                  NaN               NaN
# ..                  ...                  ...               ...
# 569               06:00                13:15             06:00
# 570               05:45                11:10             05:45
# 571               06:15                20:00             06:15
# 572               06:00                13:15             06:00
# 573                 NaN                  NaN               NaN
#
#      sales_close_friday  sales_open_saturday  sales_close_saturday  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   NaN                  NaN                   NaN
# 4                   NaN                  NaN                   NaN
# ..                  ...                  ...                   ...
# 569               13:15                07:00                 14:15
# 570               11:10                07:00                 12:10
# 571               20:00                06:30                 20:00
# 572               13:15                07:00                 14:15
# 573                 NaN                  NaN                   NaN
#
#      sales_open_sunday  sales_close_sunday
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ..                 ...                 ...
# 569                NaN                 NaN
# 570              07:00               12:10
# 571              06:30               20:00
# 572              07:00               14:15
# 573                NaN                 NaN
#
# [574 rows x 46 columns]

# %%
stations_facilities['days_open'] = stations_facilities[['sales_open_monday', 'sales_open_tuesday', 'sales_open_wednesday', 'sales_open_thursday', 'sales_open_friday', 'sales_open_saturday', 'sales_open_sunday']].notna().sum(axis = 1)
stations_facilities
# Out:
#      station_id                 name_x alternative-fr alternative-nl  \
# 0       8811007  Schaarbeek/Schaerbeek     Schaerbeek     Schaarbeek
# 1       8811106                  Evere            NaN            NaN
# 2       8811130   Haren-Sud/Haren-Zuid      Haren-Sud     Haren-Zuid
# 3       8811148                   Buda            NaN            NaN
# 4       8811155                  Haren            NaN            NaN
# ..          ...                    ...            ...            ...
# 569     8896503                  Ieper          Ypres            NaN
# 570     8896735              Poperinge            NaN            NaN
# 571     8896800              Roeselare        Roulers            NaN
# 572     8896909                 Izegem            NaN            NaN
# 573     8896925           Ingelmunster            NaN            NaN
#
#     alternative-de alternative-en country-code  longitude   latitude  \
# 0              NaN            NaN           be   4.378636  50.878513
# 1              NaN            NaN           be   4.400965  50.867780
# 2              NaN            NaN           be   4.415357  50.889696
# 3              NaN            NaN           be   4.417074  50.907495
# 4              NaN            NaN           be   4.419978  50.888878
# ..             ...            ...          ...        ...        ...
# 569            NaN            NaN           be   2.876593  50.847402
# 570            NaN            NaN           be   2.736343  50.854449
# 571            NaN            NaN           be   3.130412  50.949025
# 572            NaN            NaN           be   3.212088  50.921149
# 573            NaN            NaN           be   3.255416  50.914326
#
#      avg_stop_times  ...  sales_close_wednesday sales_open_thursday  \
# 0        737.231343  ...                    NaN                 NaN
# 1        166.641791  ...                    NaN                 NaN
# 2        324.111940  ...                    NaN                 NaN
# 3        208.134328  ...                    NaN                 NaN
# 4        166.641791  ...                    NaN                 NaN
# ..              ...  ...                    ...                 ...
# 569       42.067164  ...                  13:15               06:00
# 570       41.544776  ...                  11:10               05:45
# 571       68.574627  ...                  20:00               06:15
# 572       68.574627  ...                  13:15               06:00
# 573       68.574627  ...                    NaN                 NaN
#
#     sales_close_thursday sales_open_friday sales_close_friday  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ..                   ...               ...                ...
# 569                13:15             06:00              13:15
# 570                11:10             05:45              11:10
# 571                20:00             06:15              20:00
# 572                13:15             06:00              13:15
# 573                  NaN               NaN                NaN
#
#      sales_open_saturday  sales_close_saturday  sales_open_sunday  \
# 0                    NaN                   NaN                NaN
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# ..                   ...                   ...                ...
# 569                07:00                 14:15                NaN
# 570                07:00                 12:10              07:00
# 571                06:30                 20:00              06:30
# 572                07:00                 14:15              07:00
# 573                  NaN                   NaN                NaN
#
#      sales_close_sunday  days_open
# 0                   NaN          0
# 1                   NaN          0
# 2                   NaN          0
# 3                   NaN          0
# 4                   NaN          0
# ..                  ...        ...
# 569                 NaN          6
# 570               12:10          7
# 571               20:00          7
# 572               14:15          7
# 573                 NaN          0
#
# [574 rows x 47 columns]

# %%
stations_facilities.rename(columns={'name_x': 'station'}, inplace=True)

# %%
stations_facilities['station'] = stations_facilities['station'].str.lower()
satisfaction['station'] = satisfaction['station'].str.lower()
merged = pd.merge(stations_facilities, satisfaction, on='station', how='left')
merged = merged.drop(columns=['Unnamed: 0'])
merged
# Out:
#      station_id                station alternative-fr alternative-nl  \
# 0       8811007  schaarbeek/schaerbeek     Schaerbeek     Schaarbeek
# 1       8811106                  evere            NaN            NaN
# 2       8811130   haren-sud/haren-zuid      Haren-Sud     Haren-Zuid
# 3       8811148                   buda            NaN            NaN
# 4       8811155                  haren            NaN            NaN
# ..          ...                    ...            ...            ...
# 569     8896503                  ieper          Ypres            NaN
# 570     8896735              poperinge            NaN            NaN
# 571     8896800              roeselare        Roulers            NaN
# 572     8896909                 izegem            NaN            NaN
# 573     8896925           ingelmunster            NaN            NaN
#
#     alternative-de alternative-en country-code  longitude   latitude  \
# 0              NaN            NaN           be   4.378636  50.878513
# 1              NaN            NaN           be   4.400965  50.867780
# 2              NaN            NaN           be   4.415357  50.889696
# 3              NaN            NaN           be   4.417074  50.907495
# 4              NaN            NaN           be   4.419978  50.888878
# ..             ...            ...          ...        ...        ...
# 569            NaN            NaN           be   2.876593  50.847402
# 570            NaN            NaN           be   2.736343  50.854449
# 571            NaN            NaN           be   3.130412  50.949025
# 572            NaN            NaN           be   3.212088  50.921149
# 573            NaN            NaN           be   3.255416  50.914326
#
#      avg_stop_times  ...  sales_open_thursday sales_close_thursday  \
# 0        737.231343  ...                  NaN                  NaN
# 1        166.641791  ...                  NaN                  NaN
# 2        324.111940  ...                  NaN                  NaN
# 3        208.134328  ...                  NaN                  NaN
# 4        166.641791  ...                  NaN                  NaN
# ..              ...  ...                  ...                  ...
# 569       42.067164  ...                06:00                13:15
# 570       41.544776  ...                05:45                11:10
# 571       68.574627  ...                06:15                20:00
# 572       68.574627  ...                06:00                13:15
# 573       68.574627  ...                  NaN                  NaN
#
#     sales_open_friday sales_close_friday sales_open_saturday  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
# ..                ...                ...                 ...
# 569             06:00              13:15               07:00
# 570             05:45              11:10               07:00
# 571             06:15              20:00               06:30
# 572             06:00              13:15               07:00
# 573               NaN                NaN                 NaN
#
#      sales_close_saturday  sales_open_sunday  sales_close_sunday  days_open  \
# 0                     NaN                NaN                 NaN          0
# 1                     NaN                NaN                 NaN          0
# 2                     NaN                NaN                 NaN          0
# 3                     NaN                NaN                 NaN          0
# 4                     NaN                NaN                 NaN          0
# ..                    ...                ...                 ...        ...
# 569                 14:15                NaN                 NaN          6
# 570                 12:10              07:00               12:10          7
# 571                 20:00              06:30               20:00          7
# 572                 14:15              07:00               14:15          7
# 573                   NaN                NaN                 NaN          0
#
#      Avg Satisfaction
# 0                 NaN
# 1               41.76
# 2                 NaN
# 3               18.35
# 4               40.14
# ..                ...
# 569             49.95
# 570             61.95
# 571             58.54
# 572             60.08
# 573             67.75
#
# [574 rows x 48 columns]
